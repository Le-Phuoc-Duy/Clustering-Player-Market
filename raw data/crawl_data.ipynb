# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
BASE_URL = 'https://www.sofascore.com'
UEFA_RANKINGS_URL = 'https://www.sofascore.com/football/rankings/uefa'

COUNTRY_RANKINGS_URL = 'https://api.sofascore.com/api/v1/rankings/season/2024/type/1'
CLUB_RANKINGS_URL = 'https://api.sofascore.com/api/v1/rankings/type/9'

TEAM_URL = BASE_URL + '/team/football'

headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'
}

# %% [markdown]
# ### Lưu dữ liệu

# %%
### Xuất dữ liệu vào file csv
def create_csv_file(data, filename, header=True):
  df = pd.DataFrame(data)
  df.to_csv(filename, mode='a', index=False, header=header)

# %% [markdown]
# ### Lấy danh sách các nước với các hệ số thích hợp

# %%
def scrape_country_rankings(country_rankings_url=COUNTRY_RANKINGS_URL, threshold=0.75):
  response = requests.get(country_rankings_url, headers=headers)
  if response.status_code != 200:
    print('Failed to fetch page')
    return
  
  data = response.json()

  df = pd.DataFrame(data['rankings'])
  countries = []

  for index, row in df.iterrows():
    if len(countries) == 0 or (row['points'] < countries[-1]['points'] - threshold and row['uniqueTournament']['name'] not in [country['name'] for country in countries]):
      countries.append({
        'name': row['uniqueTournament']['name'],
        'country': row['uniqueTournament']['category']['country']['name'],
        'points': row['points'],
      })

  create_csv_file(countries, 'country_rankings.csv')

# scrape_country_rankings()

# %% [markdown]
# ### Lấy danh sách các Câu lạc bộ thuộc các nước đã chọn cùng với có hệ số thích hợp

# %%
def scrape_club_rankings(club_rankings_url=CLUB_RANKINGS_URL, threshold=0.5):
  response = requests.get(club_rankings_url, headers=headers)
  if response.status_code != 200:
    print('Failed to fetch page')
    return
  
  data = response.json()

  df = pd.DataFrame(data['rankings'])
  clubs = []

  countries = pd.read_csv('country_rankings.csv')

  for index, row in df.iterrows():
    if row['team']['country']['name'] in countries['country'].values and (len(clubs) == 0 or row['team']['name'] not in [club['name'] for club in clubs]):
      clubs.append({
        'name': row['team']['name'],
        'country': row['team']['country']['name'],
        'points': row['points'],
        'path': '/' + row['team']['slug'] + '/' + str(row['team']['id'])
      })

  create_csv_file(clubs, 'club_rankings.csv')

# scrape_club_rankings()

# %% [markdown]
# ### Lấy link của các cầu thủ

# %%
def scrape_player_pages(team_base_url=TEAM_URL):
  link_players = []

  clubs = pd.read_csv('club_rankings.csv')
  club_urls = team_base_url + clubs['path']

  for club_url in club_urls:
    print('Scraping club:', club_url)
    response = requests.get(club_url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')

    div_players = soup.find_all('div', class_='sc-fqkvVR fSBPoD')
    
    if div_players:
      for player in div_players:
        player_url = player.find('a')
        if player_url:
          link_players.append(player_url.get('href'))

  filename = 'player_links.csv'
  create_csv_file(link_players, filename, header=False)

# scrape_player_pages()

# %% [markdown]
# ### Main

# %%
# Lấy danh sách các quốc gia và số điểm của họ
scrape_country_rankings()
# Lấy danh sách các câu lạc bộ và số điểm của họ
scrape_club_rankings()
# Lấy danh sách liên kết của các cầu thủ từ các tiêu chí đã chọn
scrape_player_pages()
print("Scraping player links completed.")
# Out:
# Scraping club: https://www.sofascore.com/team/football/manchester-city/17
# Scraping club: https://www.sofascore.com/team/football/fc-bayern-munchen/2672
# Scraping club: https://www.sofascore.com/team/football/real-madrid/2829
# Scraping club: https://www.sofascore.com/team/football/paris-saint-germain/1644
# Scraping club: https://www.sofascore.com/team/football/liverpool/44
# Scraping club: https://www.sofascore.com/team/football/inter/2697
# Scraping club: https://www.sofascore.com/team/football/rb-leipzig/36360
# Scraping club: https://www.sofascore.com/team/football/chelsea/38
# Scraping club: https://www.sofascore.com/team/football/roma/2702
# Scraping club: https://www.sofascore.com/team/football/manchester-united/35
# Scraping club: https://www.sofascore.com/team/football/borussia-dortmund/2673
# Scraping club: https://www.sofascore.com/team/football/barcelona/2817
# Scraping club: https://www.sofascore.com/team/football/atletico-madrid/2836
# Scraping club: https://www.sofascore.com/team/football/sevilla/2833
# Scraping club: https://www.sofascore.com/team/football/bayer-04-leverkusen/2681
# Scraping club: https://www.sofascore.com/team/football/villarreal/2819
# Scraping club: https://www.sofascore.com/team/football/juventus/2687
# Scraping club: https://www.sofascore.com/team/football/napoli/2714
# Scraping club: https://www.sofascore.com/team/football/fc-porto/3002
# Scraping club: https://www.sofascore.com/team/football/benfica/3006
# Scraping club: https://www.sofascore.com/team/football/atalanta/2686
# Scraping club: https://www.sofascore.com/team/football/arsenal/42
# Scraping club: https://www.sofascore.com/team/football/west-ham-united/37
# Scraping club: https://www.sofascore.com/team/football/ajax/2953
# Scraping club: https://www.sofascore.com/team/football/rangers/2351
# Scraping club: https://www.sofascore.com/team/football/eintracht-frankfurt/2674
# Scraping club: https://www.sofascore.com/team/football/milan/2692
# Scraping club: https://www.sofascore.com/team/football/club-brugge-kv/2888
# Scraping club: https://www.sofascore.com/team/football/feyenoord/2959
# Scraping club: https://www.sofascore.com/team/football/sporting/3001
# Scraping club: https://www.sofascore.com/team/football/psv-eindhoven/2952
# Scraping club: https://www.sofascore.com/team/football/tottenham-hotspur/33
# Scraping club: https://www.sofascore.com/team/football/lazio/2699
# Scraping club: https://www.sofascore.com/team/football/basel/2501
# Scraping club: https://www.sofascore.com/team/football/real-sociedad/2824
# Scraping club: https://www.sofascore.com/team/football/gnk-dinamo-zagreb/2032
# Scraping club: https://www.sofascore.com/team/football/az-alkmaar/2950
# Scraping club: https://www.sofascore.com/team/football/sporting-braga/2999
# Scraping club: https://www.sofascore.com/team/football/lille/1643
# Scraping club: https://www.sofascore.com/team/football/gent/2903
# Scraping club: https://www.sofascore.com/team/football/olympique-de-marseille/1641
# Scraping club: https://www.sofascore.com/team/football/olympique-lyonnais/1649
# Scraping club: https://www.sofascore.com/team/football/stade-rennais/1658
# Scraping club: https://www.sofascore.com/team/football/fk-crvena-zvezda/5149
# Scraping club: https://www.sofascore.com/team/football/olympiacos-fc/3245
# Scraping club: https://www.sofascore.com/team/football/paok/3251
# Scraping club: https://www.sofascore.com/team/football/young-boys/2445
# Scraping club: https://www.sofascore.com/team/football/fenerbahce/3052
# Scraping club: https://www.sofascore.com/team/football/fiorentina/2693
# Scraping club: https://www.sofascore.com/team/football/real-betis/2816
# Scraping club: https://www.sofascore.com/team/football/celtic/2352
# Scraping club: https://www.sofascore.com/team/football/galatasaray/3061
# Scraping club: https://www.sofascore.com/team/football/basaksehir-fk/3086
# Scraping club: https://www.sofascore.com/team/football/molde-fk/661
# Scraping club: https://www.sofascore.com/team/football/bodoglimt/656
# Scraping club: https://www.sofascore.com/team/football/sc-freiburg/2538
# Scraping club: https://www.sofascore.com/team/football/royale-union-saint-gilloise/4860
# Scraping club: https://www.sofascore.com/team/football/ludogorets/43840
# Scraping club: https://www.sofascore.com/team/football/fk-partizan/5152
# Scraping club: https://www.sofascore.com/team/football/royal-antwerp-fc/2889
# Scraping club: https://www.sofascore.com/team/football/leicester-city/31
# Scraping club: https://www.sofascore.com/team/football/1-fc-union-berlin/2547
# Scraping club: https://www.sofascore.com/team/football/vfl-wolfsburg/2524
# Scraping club: https://www.sofascore.com/team/football/zenit-st-petersburg/2321
# Scraping club: https://www.sofascore.com/team/football/borussia-mgladbach/2527
# Scraping club: https://www.sofascore.com/team/football/newcastle-united/39
# Scraping club: https://www.sofascore.com/team/football/wolverhampton/3
# Scraping club: https://www.sofascore.com/team/football/brighton-and-hove-albion/30
# Scraping club: https://www.sofascore.com/team/football/aston-villa/40
# Scraping club: https://www.sofascore.com/team/football/granada/33779
# Scraping club: https://www.sofascore.com/team/football/getafe/2859
# Scraping club: https://www.sofascore.com/team/football/espanyol/2814
# Scraping club: https://www.sofascore.com/team/football/valencia/2828
# Scraping club: https://www.sofascore.com/team/football/osasuna/2820
# Scraping club: https://www.sofascore.com/team/football/torino/2696
# Scraping club: https://www.sofascore.com/team/football/nice/1661
# Scraping club: https://www.sofascore.com/team/football/tsg-hoffenheim/2569
# Scraping club: https://www.sofascore.com/team/football/1-fc-koln/2671
# Scraping club: https://www.sofascore.com/team/football/sivasspor/3076
# Scraping club: https://www.sofascore.com/team/football/lokomotiv-moscow/2320
# Scraping club: https://www.sofascore.com/team/football/krc-genk/2890
# Scraping club: https://www.sofascore.com/team/football/spartak-moscow/2323
# Scraping club: https://www.sofascore.com/team/football/anderlecht/2900
# Scraping club: https://www.sofascore.com/team/football/apoel-nicosia/3398
# Scraping club: https://www.sofascore.com/team/football/fc-krasnodar/34425
# Scraping club: https://www.sofascore.com/team/football/nantes/1647
# Scraping club: https://www.sofascore.com/team/football/toulouse/1681
# Scraping club: https://www.sofascore.com/team/football/rc-lens/404737
# Scraping club: https://www.sofascore.com/team/football/rc-strasbourg/1659
# Scraping club: https://www.sofascore.com/team/football/saint-etienne/1678
# Scraping club: https://www.sofascore.com/team/football/stade-de-reims/1682
# Scraping club: https://www.sofascore.com/team/football/cska-sofia/3275
# Scraping club: https://www.sofascore.com/team/football/fc-twente/2955
# Scraping club: https://www.sofascore.com/team/football/willem-ii-tilburg/2961
# Scraping club: https://www.sofascore.com/team/football/fc-utrecht/2948
# Scraping club: https://www.sofascore.com/team/football/vitesse/2958
# Scraping club: https://www.sofascore.com/team/football/besiktas/3050
# Scraping club: https://www.sofascore.com/team/football/omonia-nicosia/3395
# Scraping club: https://www.sofascore.com/team/football/hnk-rijeka/2039
# Scraping club: https://www.sofascore.com/team/football/trabzonspor/3051
# Scraping club: https://www.sofascore.com/team/football/aberdeen/2355
# Scraping club: https://www.sofascore.com/team/football/rio-ave/3036
# Scraping club: https://www.sofascore.com/team/football/vitoria-sc/3009
# Scraping club: https://www.sofascore.com/team/football/santa-clara/3011
# Scraping club: https://www.sofascore.com/team/football/pacos-de-ferreira/3003
# Scraping club: https://www.sofascore.com/team/football/arouca/25777
# Scraping club: https://www.sofascore.com/team/football/gil-vicente/3010
# Scraping club: https://www.sofascore.com/team/football/apollon-limassol/3402
# Scraping club: https://www.sofascore.com/team/football/nk-olimpija-ljubljana/2416
# Scraping club: https://www.sofascore.com/team/football/aek-athens/3250
# Scraping club: https://www.sofascore.com/team/football/rosenborg-bk/1161
# Scraping club: https://www.sofascore.com/team/football/standard-liege/2901
# Scraping club: https://www.sofascore.com/team/football/rc-sporting-charleroi/2898
# Scraping club: https://www.sofascore.com/team/football/nk-maribor/2420
# Scraping club: https://www.sofascore.com/team/football/bate-borisov/3350
# Scraping club: https://www.sofascore.com/team/football/aris-thessaloniki/3252
# Scraping club: https://www.sofascore.com/team/football/servette-fc/2448
# Scraping club: https://www.sofascore.com/team/football/lincoln-red-imps/126304
# Scraping club: https://www.sofascore.com/team/football/hnk-hajduk-split/2036
# Scraping club: https://www.sofascore.com/team/football/f91-dudelange/5207
# Scraping club: https://www.sofascore.com/team/football/nk-osijek/2040
# Scraping club: https://www.sofascore.com/team/football/breidablik-kopavogur/1901
# Scraping club: https://www.sofascore.com/team/football/the-new-saints/4921
# Scraping club: https://www.sofascore.com/team/football/fc-ararat-armenia/262229
# Scraping club: https://www.sofascore.com/team/football/pyunik-yerevan/5214
# Scraping club: https://www.sofascore.com/team/football/fk-cukaricki/5148
# Scraping club: https://www.sofascore.com/team/football/fc-lugano/2443
# Scraping club: https://www.sofascore.com/team/football/aek-larnaca/3404
# Scraping club: https://www.sofascore.com/team/football/dinamo-tbilisi/5171
# Scraping club: https://www.sofascore.com/team/football/konyaspor/3085
# Scraping club: https://www.sofascore.com/team/football/alanyaspor/6362
# Scraping club: https://www.sofascore.com/team/football/yeni-malatyaspor/24759
# Scraping club: https://www.sofascore.com/team/football/adana-demirspor/3101
# Scraping club: https://www.sofascore.com/team/football/fc-alashkert/67966
# Scraping club: https://www.sofascore.com/team/football/dundee-united/2349
# Scraping club: https://www.sofascore.com/team/football/kilmarnock/2347
# Scraping club: https://www.sofascore.com/team/football/st-johnstone/2348
# Scraping club: https://www.sofascore.com/team/football/heart-of-midlothian/2353
# Scraping club: https://www.sofascore.com/team/football/motherwell/2346
# Scraping club: https://www.sofascore.com/team/football/hibernian/2354
# Scraping club: https://www.sofascore.com/team/football/cska-moscow/2325
# Scraping club: https://www.sofascore.com/team/football/anorthosis-famagusta/3403
# Scraping club: https://www.sofascore.com/team/football/ns-mura/213357
# Scraping club: https://www.sofascore.com/team/football/fc-luzern/2453
# Scraping club: https://www.sofascore.com/team/football/fc-thun/2454
# Scraping club: https://www.sofascore.com/team/football/fc-sankt-gallen-staad/326525
# Scraping club: https://www.sofascore.com/team/football/fc-zurich/2450
# Scraping club: https://www.sofascore.com/team/football/fc-drita/229755
# Scraping club: https://www.sofascore.com/team/football/shakhtyor-soligorsk/3357
# Scraping club: https://www.sofascore.com/team/football/sk-brann/1159
# Scraping club: https://www.sofascore.com/team/football/haugesund/673
# Scraping club: https://www.sofascore.com/team/football/valerenga-if/1165
# Scraping club: https://www.sofascore.com/team/football/lillestrom-sk/664
# Scraping club: https://www.sofascore.com/team/football/viking-fk/1164
# Scraping club: https://www.sofascore.com/team/football/cs-fola-esch/25929
# Scraping club: https://www.sofascore.com/team/football/kf-ballkani/230417
# Scraping club: https://www.sofascore.com/team/football/levski-sofia/3273
# Scraping club: https://www.sofascore.com/team/football/panathinaikos/3248
# Scraping club: https://www.sofascore.com/team/football/atromitos-athens/5062
# Scraping club: https://www.sofascore.com/team/football/ofi-crete/3241
# Scraping club: https://www.sofascore.com/team/football/fk-radnicki-nis/25737
# Scraping club: https://www.sofascore.com/team/football/fk-vojvodina/5150
# Scraping club: https://www.sofascore.com/team/football/fk-tsc-backa-topola/263360
# Scraping club: https://www.sofascore.com/team/football/sp-tre-penne/37862
# Scraping club: https://www.sofascore.com/team/football/lokomotiv-plovdiv/3272
# Scraping club: https://www.sofascore.com/team/football/connahs-quay-nomads/4912
# Scraping club: https://www.sofascore.com/team/football/europa-fc/126298
# Scraping club: https://www.sofascore.com/team/football/dinamo-batumi/37297
# Scraping club: https://www.sofascore.com/team/football/nk-lokomotiva-zagreb/36246
# Scraping club: https://www.sofascore.com/team/football/progres-niederkorn/36201
# Scraping club: https://www.sofascore.com/team/football/la-fiorita/37860
# Scraping club: https://www.sofascore.com/team/football/dinamo-minsk/3361
# Scraping club: https://www.sofascore.com/team/football/aris-limassol/3397
# Scraping club: https://www.sofascore.com/team/football/fc-iberia-1999/116312
# Scraping club: https://www.sofascore.com/team/football/nk-celje/2413
# Scraping club: https://www.sofascore.com/team/football/nk-domzale/2418
# Scraping club: https://www.sofascore.com/team/football/ael-limassol/3407
# Scraping club: https://www.sofascore.com/team/football/botev-plovdiv/5241
# Scraping club: https://www.sofascore.com/team/football/slavia-sofia/3274
# Scraping club: https://www.sofascore.com/team/football/fc-cska-1948-sofia/252080
# Scraping club: https://www.sofascore.com/team/football/arda-kardzhali/274971
# Scraping club: https://www.sofascore.com/team/football/vikingur-reykjavik/1908
# Scraping club: https://www.sofascore.com/team/football/fc-dila-gori/33819
# Scraping club: https://www.sofascore.com/team/football/st-josephs-fc/126312
# Scraping club: https://www.sofascore.com/team/football/dynamo-brest/3353
# Scraping club: https://www.sofascore.com/team/football/dynamo-moscow/2315
# Scraping club: https://www.sofascore.com/team/football/arsenal-tula/35301
# Scraping club: https://www.sofascore.com/team/football/fc-rostov/2326
# Scraping club: https://www.sofascore.com/team/football/rubin-kazan/2333
# Scraping club: https://www.sofascore.com/team/football/fc-sochi/2334
# Scraping club: https://www.sofascore.com/team/football/kr-reykjavik/38159
# Scraping club: https://www.sofascore.com/team/football/sp-tre-fiori/36195
# Scraping club: https://www.sofascore.com/team/football/urartu/5225
# Scraping club: https://www.sofascore.com/team/football/differdange-fc-03/7605
# Scraping club: https://www.sofascore.com/team/football/bala-town/36255
# Scraping club: https://www.sofascore.com/team/football/torpedo-belaz-zhodino/3359
# Scraping club: https://www.sofascore.com/team/football/sc-gjilani/229758
# Scraping club: https://www.sofascore.com/team/football/valur-reykjavik/1899
# Scraping club: https://www.sofascore.com/team/football/swift-hesperange/5382
# Scraping club: https://www.sofascore.com/team/football/fc-prishtina/229752
# Scraping club: https://www.sofascore.com/team/football/fc-koper/2417
# Scraping club: https://www.sofascore.com/team/football/fc-torpedo-kutaisi/5419
# Scraping club: https://www.sofascore.com/team/football/racing-fc-union-luxembourg/5261
# Scraping club: https://www.sofascore.com/team/football/stjarnan-gardabaer/1912
# Scraping club: https://www.sofascore.com/team/football/fh-hafnarfjordur/1894
# Scraping club: https://www.sofascore.com/team/football/fc-ararat/5377
# Scraping club: https://www.sofascore.com/team/football/newtown-afc/4918
# Scraping club: https://www.sofascore.com/team/football/kf-llapi/229761
# Scraping club: https://www.sofascore.com/team/football/dukagjini/230411
# Scraping club: https://www.sofascore.com/team/football/kf-feronikeli-74/229757
# Scraping club: https://www.sofascore.com/team/football/fc-noah/262228
# Scraping club: https://www.sofascore.com/team/football/fc-shirak-gyumri/33817
# Scraping club: https://www.sofascore.com/team/football/lokomotivi-tbilisi/5170
# Scraping club: https://www.sofascore.com/team/football/ka-akureyri/1904
# Scraping club: https://www.sofascore.com/team/football/neman-grodno/3356
# Scraping club: https://www.sofascore.com/team/football/fc-brunos-magpies/255156
# Scraping club: https://www.sofascore.com/team/football/union-titus-petange/5378
# Scraping club: https://www.sofascore.com/team/football/jeunesse-esch/5383
# Scraping club: https://www.sofascore.com/team/football/chikhura-sachkhere/37296
# Scraping club: https://www.sofascore.com/team/football/fc-gagra/36865
# Scraping club: https://www.sofascore.com/team/football/ss-folgore-falciano/37863
# Scraping club: https://www.sofascore.com/team/football/fk-gomel/3349
# Scraping club: https://www.sofascore.com/team/football/haverfordwest-county-afc/4915
# Scraping club: https://www.sofascore.com/team/football/vitebsk/3351
# Scraping club: https://www.sofascore.com/team/football/barry-town/35186
# Scraping club: https://www.sofascore.com/team/football/penybont/115185
# Scraping club: https://www.sofascore.com/team/football/cardiff-city/61
# Scraping club: https://www.sofascore.com/team/football/ss-cosmos/37864
# Scraping club: https://www.sofascore.com/team/football/mons-calpe/232548
# Scraping player links completed.
